# %% [markdown]
# # 测试集总体准确率评估指标
#
# 分析测试集预测结果表格，计算总体准确率评估指标和各类别准确率评估指标。
#
# 同济子豪兄：https://space.bilibili.com/1900783

# %% [markdown]
# ## 导入工具包

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## 载入类别名称和ID

# %%
idx_to_labels = np.load('idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# ['哈密瓜', '圣女果', '山竹', '杨梅', '柚子', '柠檬', '桂圆', '梨', '椰子', '榴莲', '火龙果', '猕猴桃', '石榴', '砂糖橘', '胡萝卜', '脐橙', '芒果', '苦瓜', '苹果-红', '苹果-青', '草莓', '荔枝', '菠萝', '葡萄-白', '葡萄-红', '西瓜', '西红柿', '车厘子', '香蕉', '黄瓜']

# %% [markdown]
# ## 载入测试集预测结果表格

# %%
df = pd.read_csv('测试集预测结果.csv')

# %%
df
# Out:
#                                           图像路径  标注类别ID 标注类别名称  top-1-预测ID  \
# 0     ..\..\data\fruit30_split\val\哈密瓜\106.jpg       0    哈密瓜           4
# 1     ..\..\data\fruit30_split\val\哈密瓜\109.jpg       0    哈密瓜           0
# 2     ..\..\data\fruit30_split\val\哈密瓜\114.jpg       0    哈密瓜           0
# 3     ..\..\data\fruit30_split\val\哈密瓜\116.jpg       0    哈密瓜           0
# 4     ..\..\data\fruit30_split\val\哈密瓜\118.png       0    哈密瓜           4
# ...                                        ...     ...    ...         ...
# 1073    ..\..\data\fruit30_split\val\黄瓜\87.jpg      29     黄瓜          29
# 1074     ..\..\data\fruit30_split\val\黄瓜\9.jpg      29     黄瓜          29
# 1075    ..\..\data\fruit30_split\val\黄瓜\91.png      29     黄瓜          29
# 1076    ..\..\data\fruit30_split\val\黄瓜\94.jpg      29     黄瓜          29
# 1077    ..\..\data\fruit30_split\val\黄瓜\97.jpg      29     黄瓜          29
#
#      top-1-预测名称  top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  top-n预测正确  ...  \
# 0            柚子           0        哈密瓜           5         柠檬       True  ...
# 1           哈密瓜           6         桂圆           8         椰子       True  ...
# 2           哈密瓜          26        西红柿           2         山竹       True  ...
# 3           哈密瓜          16         芒果           9         榴莲       True  ...
# 4            柚子          11        猕猴桃           0        哈密瓜       True  ...
# ...         ...         ...        ...         ...        ...        ...  ...
# 1073         黄瓜          25         西瓜          17         苦瓜       True  ...
# 1074         黄瓜          17         苦瓜          19       苹果-青       True  ...
# 1075         黄瓜          17         苦瓜          23       葡萄-白       True  ...
# 1076         黄瓜          17         苦瓜          10        火龙果       True  ...
# 1077         黄瓜          17         苦瓜          25         西瓜       True  ...
#
#           草莓-预测置信度      荔枝-预测置信度      菠萝-预测置信度    葡萄-白-预测置信度    葡萄-红-预测置信度  \
# 0     3.521001e-07  2.308949e-06  2.254164e-06  1.504217e-06  5.554669e-07
# 1     2.910540e-07  1.311537e-05  7.039090e-07  1.404879e-03  2.569432e-05
# 2     4.027732e-03  8.896847e-03  3.352876e-04  5.858226e-03  1.932197e-03
# 3     1.913530e-05  3.439658e-04  1.499393e-05  1.238798e-04  1.947595e-07
# 4     1.959296e-03  6.960726e-05  4.301105e-05  1.677096e-02  3.243645e-05
# ...            ...           ...           ...           ...           ...
# 1073  1.514343e-08  3.062722e-09  8.348586e-10  3.020065e-06  1.620257e-10
# 1074  8.390700e-08  2.495038e-08  1.880084e-08  5.509225e-08  3.612168e-09
# 1075  2.649291e-04  3.746343e-03  3.782225e-05  4.321362e-03  5.086012e-05
# 1076  7.608221e-04  7.951188e-06  1.652561e-04  3.332345e-04  9.151688e-05
# 1077  4.436936e-05  8.927602e-08  8.894688e-06  7.491136e-06  5.141735e-07
#
#       西瓜-预测置信度     西红柿-预测置信度     车厘子-预测置信度      香蕉-预测置信度      黄瓜-预测置信度
# 0     0.000134  1.167948e-05  3.926038e-06  3.790720e-05  1.814037e-07
# 1     0.000182  2.765986e-07  1.779288e-05  1.000518e-03  4.129508e-06
# 2     0.000411  1.927615e-02  2.409854e-04  3.670266e-03  1.477481e-04
# 3     0.000130  5.474818e-05  2.550467e-07  9.668104e-03  8.494197e-05
# 4     0.000834  6.195806e-04  1.078881e-07  1.307024e-03  2.273609e-04
# ...        ...           ...           ...           ...           ...
# 1073  0.001805  1.007305e-07  8.860658e-09  1.527792e-06  9.978435e-01
# 1074  0.000004  2.541479e-08  1.107946e-07  7.836900e-07  9.994579e-01
# 1075  0.000028  4.023723e-05  3.551200e-06  2.648318e-04  8.883497e-01
# 1076  0.001328  1.998427e-05  1.160606e-05  2.149590e-04  9.693536e-01
# 1077  0.000098  1.389878e-07  3.806196e-07  1.250567e-06  9.958375e-01
#
# [1078 rows x 40 columns]

# %% [markdown]
# ## 准确率

# %%
sum(df['标注类别名称'] == df['top-1-预测名称']) / len(df)
# Out:
# 0.8682745825602969

# %% [markdown]
# ## top-n准确率

# %%
sum(df['top-n预测正确']) / len(df)
# Out:
# 0.9703153988868275

# %% [markdown]
# ## 各类别其它评估指标
#
# 公众号 人工智能小技巧 回复 混淆矩阵
#
# 看子豪兄视频和笔记讲解

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#          哈密瓜       0.82      0.89      0.86        37
#          圣女果       0.72      0.82      0.77        38
#           山竹       0.94      0.91      0.93        35
#           杨梅       0.89      0.86      0.88        37
#           柚子       0.70      0.84      0.77        37
#           柠檬       0.81      0.76      0.79        29
#           桂圆       0.94      0.89      0.92        38
#            梨       0.88      0.76      0.81        37
#           椰子       0.85      0.92      0.89        38
#           榴莲       0.94      0.81      0.87        36
#          火龙果       1.00      0.92      0.96        36
#          猕猴桃       0.94      0.86      0.90        37
#           石榴       0.86      0.86      0.86        37
#          砂糖橘       0.84      0.89      0.86        35
#          胡萝卜       0.97      0.89      0.93        36
#           脐橙       0.79      0.81      0.80        37
#           芒果       0.81      0.79      0.80        33
#           苦瓜       0.97      0.89      0.93        35
#         苹果-红       0.91      0.89      0.90        35
#         苹果-青       0.84      0.97      0.90        37
#           草莓       0.95      0.92      0.93        38
#           荔枝       0.73      0.92      0.81        38
#           菠萝       0.94      0.86      0.90        37
#         葡萄-白       0.97      0.94      0.95        31
#         葡萄-红       0.89      0.87      0.88        38
#           西瓜       0.81      0.92      0.86        37
#          西红柿       0.87      0.56      0.68        36
#          车厘子       0.81      0.91      0.85        32
#           香蕉       0.94      0.94      0.94        36
#           黄瓜       0.89      0.97      0.93        35
#
#     accuracy                           0.87      1078
#    macro avg       0.87      0.87      0.87      1078
# weighted avg       0.87      0.87      0.87      1078

# %% [markdown]
# macro avg 宏平均：直接将每一类的评估指标求和取平均（算数平均值）
#
# weighted avg 加权平均：按样本数量（support）加权计算评估指标的平均值

# %%
report = classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes, output_dict=True)
del report['accuracy']
df_report = pd.DataFrame(report).transpose()

# %%
df_report
# Out:
#               precision    recall  f1-score  support
# 哈密瓜            0.825000  0.891892  0.857143     37.0
# 圣女果            0.720930  0.815789  0.765432     38.0
# 山竹             0.941176  0.914286  0.927536     35.0
# 杨梅             0.888889  0.864865  0.876712     37.0
# 柚子             0.704545  0.837838  0.765432     37.0
# 柠檬             0.814815  0.758621  0.785714     29.0
# 桂圆             0.944444  0.894737  0.918919     38.0
# 梨              0.875000  0.756757  0.811594     37.0
# 椰子             0.853659  0.921053  0.886076     38.0
# 榴莲             0.935484  0.805556  0.865672     36.0
# 火龙果            1.000000  0.916667  0.956522     36.0
# 猕猴桃            0.941176  0.864865  0.901408     37.0
# 石榴             0.864865  0.864865  0.864865     37.0
# 砂糖橘            0.837838  0.885714  0.861111     35.0
# 胡萝卜            0.969697  0.888889  0.927536     36.0
# 脐橙             0.789474  0.810811  0.800000     37.0
# 芒果             0.812500  0.787879  0.800000     33.0
# 苦瓜             0.968750  0.885714  0.925373     35.0
# 苹果-红           0.911765  0.885714  0.898551     35.0
# 苹果-青           0.837209  0.972973  0.900000     37.0
# 草莓             0.945946  0.921053  0.933333     38.0
# 荔枝             0.729167  0.921053  0.813953     38.0
# 菠萝             0.941176  0.864865  0.901408     37.0
# 葡萄-白           0.966667  0.935484  0.950820     31.0
# 葡萄-红           0.891892  0.868421  0.880000     38.0
# 西瓜             0.809524  0.918919  0.860759     37.0
# 西红柿            0.869565  0.555556  0.677966     36.0
# 车厘子            0.805556  0.906250  0.852941     32.0
# 香蕉             0.944444  0.944444  0.944444     36.0
# 黄瓜             0.894737  0.971429  0.931507     35.0
# macro avg      0.874530  0.867765  0.868091   1078.0
# weighted avg   0.874202  0.868275  0.868148   1078.0

# %% [markdown]
# ## 补充：各类别准确率（其实就是recall）

# %%
accuracy_list = []
for fruit in tqdm(classes):
    df_temp = df[df['标注类别名称']==fruit]
    accuracy = sum(df_temp['标注类别名称'] == df_temp['top-1-预测名称']) / len(df_temp)
    accuracy_list.append(accuracy)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 2155.57it/s]

# %%
# 计算 宏平均准确率 和 加权平均准确率
acc_macro = np.mean(accuracy_list)
acc_weighted = sum(accuracy_list * df_report.iloc[:-2]['support'] / len(df))

accuracy_list.append(acc_macro)
accuracy_list.append(acc_weighted)

df_report['accuracy'] = accuracy_list

# %%
df_report
# Out:
#               precision    recall  f1-score  support  accuracy
# 哈密瓜            0.825000  0.891892  0.857143     37.0  0.891892
# 圣女果            0.720930  0.815789  0.765432     38.0  0.815789
# 山竹             0.941176  0.914286  0.927536     35.0  0.914286
# 杨梅             0.888889  0.864865  0.876712     37.0  0.864865
# 柚子             0.704545  0.837838  0.765432     37.0  0.837838
# 柠檬             0.814815  0.758621  0.785714     29.0  0.758621
# 桂圆             0.944444  0.894737  0.918919     38.0  0.894737
# 梨              0.875000  0.756757  0.811594     37.0  0.756757
# 椰子             0.853659  0.921053  0.886076     38.0  0.921053
# 榴莲             0.935484  0.805556  0.865672     36.0  0.805556
# 火龙果            1.000000  0.916667  0.956522     36.0  0.916667
# 猕猴桃            0.941176  0.864865  0.901408     37.0  0.864865
# 石榴             0.864865  0.864865  0.864865     37.0  0.864865
# 砂糖橘            0.837838  0.885714  0.861111     35.0  0.885714
# 胡萝卜            0.969697  0.888889  0.927536     36.0  0.888889
# 脐橙             0.789474  0.810811  0.800000     37.0  0.810811
# 芒果             0.812500  0.787879  0.800000     33.0  0.787879
# 苦瓜             0.968750  0.885714  0.925373     35.0  0.885714
# 苹果-红           0.911765  0.885714  0.898551     35.0  0.885714
# 苹果-青           0.837209  0.972973  0.900000     37.0  0.972973
# 草莓             0.945946  0.921053  0.933333     38.0  0.921053
# 荔枝             0.729167  0.921053  0.813953     38.0  0.921053
# 菠萝             0.941176  0.864865  0.901408     37.0  0.864865
# 葡萄-白           0.966667  0.935484  0.950820     31.0  0.935484
# 葡萄-红           0.891892  0.868421  0.880000     38.0  0.868421
# 西瓜             0.809524  0.918919  0.860759     37.0  0.918919
# 西红柿            0.869565  0.555556  0.677966     36.0  0.555556
# 车厘子            0.805556  0.906250  0.852941     32.0  0.906250
# 香蕉             0.944444  0.944444  0.944444     36.0  0.944444
# 黄瓜             0.894737  0.971429  0.931507     35.0  0.971429
# macro avg      0.874530  0.867765  0.868091   1078.0  0.867765
# weighted avg   0.874202  0.868275  0.868148   1078.0  0.868275

# %%
df_report.to_csv('各类别准确率评估指标.csv', index_label='类别')
